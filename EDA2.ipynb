# %% [markdown]
# ### 1. Data Exploration and Preprocessing:

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("adult_with_headers.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df[df.duplicated(keep=False)]
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 2303    90            Private   52386   Some-college             10
# 3917    19            Private  251579   Some-college             10
# 4325    25            Private  308144      Bachelors             13
# 4767    21            Private  250051   Some-college             10
# 4881    25            Private  308144      Bachelors             13
# 4940    38            Private  207202        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 5579    27            Private  255582        HS-grad              9
# 5805    20            Private  107658   Some-college             10
# 5842    25            Private  195994        1st-4th              2
# 6990    19            Private  138153   Some-college             10
# 7053    49   Self-emp-not-inc   43479   Some-college             10
# 7920    49            Private   31267        7th-8th              4
# ...

# %%
df1=df.drop_duplicates()

# %%
df1.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
numerical_cols=df1.select_dtypes(include=["int","float"])
numerical_cols.mean()
# Out:
# age                   38.585549
# fnlwgt            189780.848511
# education_num         10.081815
# capital_gain        1078.443741
# capital_loss          87.368227
# hours_per_week        40.440329
# dtype: float64

# %%
sc=StandardScaler()

# %%
df1_scaled=sc.fit_transform(numerical_cols)

# %%
df1_scaled
# Out:
# array([[ 0.03038995, -1.06356884,  1.13477712,  0.14829174, -0.21674317,
#         -0.03566374],
#        [ 0.8369732 , -1.00866848,  1.13477712, -0.14597544, -0.21674317,
#         -2.22248299],
#        [-0.0429358 ,  0.24503992, -0.42067868, -0.14597544, -0.21674317,
#         -0.03566374],
#        ...,
#        [ 1.42357919, -0.35877886, -0.42067868, -0.14597544, -0.21674317,
#         -0.03566374],
#        [-1.2161478 ,  0.11092955, -0.42067868, -0.14597544, -0.21674317,
#         -1.65552985],
#        [ 0.9836247 ,  0.92981187, -0.42067868,  1.88763548, -0.21674317,
#         -0.03566374]])

# %%
norm=MinMaxScaler()

# %%
df1_norm=norm.fit_transform(numerical_cols)

# %%
df1_norm
# Out:
# array([[0.30136986, 0.0443019 , 0.8       , 0.02174022, 0.        ,
#         0.39795918],
#        [0.45205479, 0.0482376 , 0.8       , 0.        , 0.        ,
#         0.12244898],
#        [0.28767123, 0.13811345, 0.53333333, 0.        , 0.        ,
#         0.39795918],
#        ...,
#        [0.56164384, 0.09482688, 0.53333333, 0.        , 0.        ,
#         0.39795918],
#        [0.06849315, 0.12849934, 0.53333333, 0.        , 0.        ,
#         0.19387755],
#        [0.47945205, 0.18720338, 0.53333333, 0.1502415 , 0.        ,
#         0.39795918]])

# %% [markdown]
# ###### Standard Scaling: Prefer this when you expect the data to have a normal distribution, when you're using algorithms that assume Gaussian data, or when the model requires the data to have a mean of zero (e.g., SVMs, linear regression).
# ###### Min-Max Scaling: Use this when working with neural networks or tree-based models that benefit from features on the same scale, especially if you need to constrain data within a specific range.

# %% [markdown]
# ### 2. Encoding Techniques:

# %%
categorical_cols=df1.select_dtypes(include=['object'])

# %%
categorical_cols
# Out:
#                workclass    education       marital_status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  native_country  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sn
for cols in categorical_cols:
    plt.figure(figsize=(10,5))
    sn.barplot(df1[cols].value_counts(),color='blue')

# %% [markdown]
# ### One-Hot Encoding to categorical variables with less than 5 categories.
# 1. income
# 2. sex
# 3. race

# %%
df1_dummies=pd.get_dummies(df1[['income','sex','race']],dtype='int')

# %%
df1_dummies
# Out:
#        income_ <=50K  income_ >50K  sex_ Female  sex_ Male  \
# 0                  1             0            0          1
# 1                  1             0            0          1
# 2                  1             0            0          1
# 3                  1             0            0          1
# 4                  1             0            1          0
# ...              ...           ...          ...        ...
# 32556              1             0            1          0
# 32557              0             1            0          1
# 32558              1             0            1          0
# 32559              1             0            0          1
# 32560              0             1            1          0
#
#        race_ Amer-Indian-Eskimo  race_ Asian-Pac-Islander  race_ Black  \
# 0                             0                         0            0
# 1                             0                         0            0
# ...

# %% [markdown]
# #### Label Encoding for categorical variables with more than 5 categories.
# 1. workclass
# 2. education
# 3. marital_status
# 4. occupation
# 5. relationship
# 6. native_country

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1_encoder=LabelEncoder()

# %%
encoding=pd.DataFrame(df1[['workclass','education','marital_status','occupation','relationship','native_country']])

# %%
for column in encoding:
    encoding[column]=df1_encoder.fit_transform(encoding[column])

# %%
encoding
# Out:
#        workclass  education  marital_status  occupation  relationship  \
# 0              7          9               4           1             1
# 1              6          9               2           4             0
# 2              4         11               0           6             1
# 3              4          1               2           6             0
# 4              4          9               2          10             5
# ...          ...        ...             ...         ...           ...
# 32556          4          7               2          13             5
# 32557          4         11               2           7             0
# 32558          4         11               6           1             4
# 32559          4         11               4           1             3
# 32560          5         11               2           4             5
#
#        native_country
# 0                  39
# 1                  39
# 2                  39
# 3                  39
# ...

# %% [markdown]
# ### One-Hot Encoding
# #### Pros:
# 1. No Assumptions for Nominal Data(categorical_data without a natural order)
# 2. Effective for Non linear data such as Decision Tress,Random Forest,Neural Networks
# 3. Each category is clearly seperated making it easy to understand each individual features eaisly
# #### Cons:
# 1. Increased Dimesionality which may increase computational cost and memory usage
# 2. Less Effective for Ordinal Data
# ### Label Encoding
# #### Pros:
# 1. Simplycity: It doesn't increase the no of dimensions
# 2. More Efficient Making it suitable for the datasets with large no of categorical features
# 3. It is suitable for ordinal data
# #### Cons:
# 1. It implies ordinal relationship for nominal data as well
# 2. Always it will not effective for Non linear Data

# %% [markdown]
# ### 3. Feature Engineering

# %%
# Check for skewness in numerical features
skewness = df1[['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']].skew()
skewness
# capital_gain and capital_loss are more possitively skewed
# Out:
# age                0.557663
# fnlwgt             1.447703
# education_num     -0.309500
# capital_gain      11.949403
# capital_loss       4.592702
# hours_per_week     0.228759
# dtype: float64

# %%
numerical_cols
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32537 rows x 6 columns]

# %%
bins=[0,30,45,60,100]
labels=['18-30','31-45','46-60','60+']
df1['age_group']=pd.cut(df1['age'],bins=bins,labels=labels,right=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11632\436393031.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['age_group']=pd.cut(df1['age'],bins=bins,labels=labels,right=False)

# %%
df1['capital_gain_log']=np.log1p(df1['capital_gain'])
df1['capital_loss_log']=np.log1p(df1['capital_loss'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11632\3871960712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['capital_gain_log']=np.log1p(df1['capital_gain'])
# C:\Users\User\AppData\Local\Temp\ipykernel_11632\3871960712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['capital_loss_log']=np.log1p(df1['capital_loss'])

# %%
df1['income_per_hour']=df1['capital_gain_log']/df1['hours_per_week']+1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11632\673902614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['income_per_hour']=df1['capital_gain_log']/df1['hours_per_week']+1

# %%
print(df1[['age','age_group','capital_gain','capital_gain_log','hours_per_week','income_per_hour']])
# Out:
#        age age_group  capital_gain  capital_gain_log  hours_per_week  \
# 0       39     31-45          2174          7.684784              40
# 1       50     46-60             0          0.000000              13
# 2       38     31-45             0          0.000000              40
# 3       53     46-60             0          0.000000              40
# 4       28     18-30             0          0.000000              40
# ...    ...       ...           ...               ...             ...
# 32556   27     18-30             0          0.000000              38
# 32557   40     31-45             0          0.000000              40
# 32558   58     46-60             0          0.000000              40
# 32559   22     18-30             0          0.000000              20
# 32560   52     46-60         15024          9.617471              40
#
#        income_per_hour
# 0             1.192120
# 1             1.000000
# 2             1.000000
# 3             1.000000
# ...

# %% [markdown]
# ### 4. Feature Selection:

# %%
from sklearn.ensemble import IsolationForest

# %%
iso_forest=IsolationForest(contamination=0.05,random_state=42)

# %%
outliers=iso_forest.fit_predict(numerical_cols)

# %%
df1['outliers']=outliers
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11632\2365574924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['outliers']=outliers

# %%
df1_cleaned=df1[df1['outliers']==1].drop(columns=['outliers'])

# %%
print("Original data shape:",df1.shape)
print("Data Shape after Outlier Removal:",df1_cleaned.shape)
# Out:
# Original data shape: (32537, 20)
# Data Shape after Outlier Removal: (30910, 19)
